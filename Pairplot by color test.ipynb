# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import gaussian_kde
# %matplotlib inline

# %%
forest = pd.read_csv('data/train.csv', header=0, index_col=0) #Use the Id column as an index...why not
cols = forest.columns.tolist()[:10]
cols.append("Cover_Type")
cols
# Out:
# ['Elevation',
#  'Aspect',
#  'Slope',
#  'Horizontal_Distance_To_Hydrology',
#  'Vertical_Distance_To_Hydrology',
#  'Horizontal_Distance_To_Roadways',
#  'Hillshade_9am',
#  'Hillshade_Noon',
#  'Hillshade_3pm',
#  'Horizontal_Distance_To_Fire_Points',
#  'Cover_Type']

# %%
sns.pairplot(forest[cols], hue='Cover_Type', diag_kind="kde", markers="+",plot_kws=dict(s=20, linewidth=0.2))
plt.savefig("visualizations/pairplot_rob.png")
# Out:
# //anaconda/envs/py36/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# //anaconda/envs/py36/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# //anaconda/envs/py36/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:32: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
